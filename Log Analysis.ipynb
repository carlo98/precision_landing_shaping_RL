# %% [markdown]
# # Imports

# %%
import numpy as np
import pickle
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# # Dataframe Creation

# %%
with open("shared/logs/log_12.pkl", "rb") as file_pkl:
    data = pickle.load(file_pkl)
means_train = np.array(data[0])
stds_train = np.array(data[1])
means_test = np.array(data[2])
stds_test = np.array(data[3])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_29818/3485397299.py in <module>
# ----> 1 with open("shared/logs/log_12.pkl", "rb") as file_pkl:
#       2     data = pickle.load(file_pkl)
#       3 means_train = np.array(data[0])
#       4 stds_train = np.array(data[1])
#       5 means_test = np.array(data[2])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'shared/logs/log_12.pkl'

# %% [markdown]
# # Visualization

# %%
# Visualize the result
means = means_train
stds = stds_train
x = range(0, len(means), 1)
figure(figsize=(14, 8), dpi=80)
plt.plot(x, means, 'or')
plt.plot(x, means, '-', color='gray')

plt.fill_between(x, means - stds, means + stds,
                 color='gray', alpha=0.2)
plt.xlim(0, len(means)+1);

# %%
# Visualize the result
means = means_test
stds = stds_test
x = range(0, len(means), 1)
figure(figsize=(14, 8), dpi=80)
plt.plot(x, means, 'or')
plt.plot(x, means, '-', color='gray')

plt.fill_between(x, means - stds, means + stds,
                 color='gray', alpha=0.2)
plt.xlim(0, len(means)+1);
